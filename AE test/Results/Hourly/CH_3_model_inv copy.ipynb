# %%
# !pip install scikit-optimize
# !pip install sktime
# !pip install tensorflow --user
# !pip install statsmodels --user
# !pip install xgboost --user

# %%
# Basic libraries
import os
import random
from collections import defaultdict
from datetime import datetime as dt
import warnings

import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Machine learning libraries
from sklearn.model_selection import train_test_split, TimeSeriesSplit, GridSearchCV
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    recall_score, 
    mean_squared_error, 
    mean_absolute_error, 
    mean_absolute_percentage_error, 
    r2_score, 
    mean_squared_log_error
)
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.cluster import DBSCAN
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import (
    RandomForestRegressor, 
    GradientBoostingRegressor, 
    ExtraTreesRegressor, 
    AdaBoostRegressor
)
from sklearn.neural_network import MLPRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, DotProduct, WhiteKernel
import xgboost as xgb

# Time series libraries
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_breusch_godfrey, acorr_ljungbox, het_white
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import acf, q_stat, adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAXResults
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from arch import arch_model
import pmdarima as pm
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
from sktime.forecasting.model_selection import ForecastingGridSearchCV, SlidingWindowSplitter

#Libraries for Statistical Models
import statsmodels.api as sm
from statsmodels.stats.diagnostic import acorr_breusch_godfrey, acorr_ljungbox, het_white
from scipy.stats import jarque_bera
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, q_stat, adfuller
from scipy.stats import probplot, moment

# LightGBM library
import lightgbm as lgb

# Set options
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# Functions

# %%
# add date tiem features
def add_datetime_features(df):
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index)
    df_copy = df.copy()
    
    # Extract year, month, and day information
    df_copy['year'] = df_copy.index.year
    df_copy['month'] = df_copy.index.month
    df_copy['day'] = df_copy.index.day
    df_copy['weekday'] = df_copy.index.weekday
    
    return df_copy

def generate_lagged_features(df, var, max_lag):
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index)
    ts_data = df.copy()
    for t in range(1, max_lag + 1):
        ts_data[var + '_lag' + str(t)] = ts_data[var].shift(t, freq='1D')
    # print(ts_data.head())
    # print(ts_data.tail())
    # print(ts_data.shape)
    ts_data.dropna(inplace=True)

    return ts_data

# def prepare_time_series_data(df, var, max_lag):
#     # Generate lagged features
#     lagged_data = generate_lagged_features(df, var, max_lag)
    
#     # Add datetime features
#     if not isinstance(lagged_data.index, pd.DatetimeIndex):
#         lagged_data.index = pd.to_datetime(lagged_data.index)
#     transformed_data = add_datetime_features(lagged_data)
    
#     return transformed_data

def extract_column(df, column_name):
    extracted_column = df[column_name]
    remaining_df = df.drop(column_name, axis=1)
    return remaining_df, extracted_column

# def scale_data(train_data, test_data):
#     scaler = MinMaxScaler()
#     train_scaled = scaler.fit_transform(train_data)
#     test_scaled = scaler.transform(test_data)
#     return train_scaled, test_scaled, scaler

def scale_data(train_data, test_data, target_column):
    scaler_X = MinMaxScaler()
    scaler_Y = MinMaxScaler()
    
    train_X = train_data.drop(target_column, axis=1)
    train_Y = train_data[[target_column]]
    
    test_X = test_data.drop(target_column, axis=1)
    test_Y = test_data[[target_column]]
    
    train_X_scaled = scaler_X.fit_transform(train_X)
    train_Y_scaled = scaler_Y.fit_transform(train_Y)
    
    test_X_scaled = scaler_X.transform(test_X)
    test_Y_scaled = scaler_Y.transform(test_Y)
    
    train_data_scaled = np.concatenate((train_X_scaled, train_Y_scaled), axis=1)
    test_data_scaled = np.concatenate((test_X_scaled, test_Y_scaled), axis=1)
    
    return train_data_scaled, test_data_scaled, scaler_X, scaler_Y


def unscale_data(pred, actual, scaler):
    pred = scaler.inverse_transform(pred)
    actual = scaler.inverse_transform(actual)
    return pred, actual

# %%
def standardize_series(series):
    return StandardScaler().fit_transform(series.values.reshape(-1, 1))

def apply_dbscan_clustering(series_standardized, eps=0.5, min_samples=2):
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    return dbscan.fit_predict(series_standardized)

def extract_outliers_from_clusters(series, clusters):
    """Identify the outliers (cluster label -1 indicates an outlier)"""
    return series[clusters == -1]

def cluster_based_outlier_detection(series):
    series_standardized = standardize_series(series)
    clusters = apply_dbscan_clustering(series_standardized, eps=0.15)
    outliers = extract_outliers_from_clusters(series, clusters)
    print('Outliers shape: {}'.format(outliers.shape))
    # Create a DataFrame with the same index as the original series
    outliers_df = pd.DataFrame(index=series.index)
    outliers_df['outliers'] = 0
    outliers_df.loc[outliers.index, 'outliers'] = 1

    return outliers_df
    
def prepare_time_series_data(df, var, max_lag, detect_outliers=False):
    # Generate lagged features
    lagged_data = generate_lagged_features(df, var, max_lag)
    # print('Lagged data shape: {}'.format(lagged_data.shape))
    
    # Add outlier features if detect_outliers is True
    if detect_outliers:
        series = df[var].pow(2)
        series.dropna(inplace=True)  
        # print('Series shape: {}'.format(series.shape))
        outliers_df = cluster_based_outlier_detection(series)
        # print('Outliers DataFrame shape: {}'.format(outliers_df.shape))
        lagged_outliers = generate_lagged_features(outliers_df, 'outliers', max_lag)
        # print('Lagged outliers shape: {}'.format(lagged_outliers.shape))
        lagged_data = lagged_data.merge(lagged_outliers, left_index=True, right_index=True)
        # print('Lagged data shape: {}'.format(lagged_data.shape))

    # Add datetime features
    if not isinstance(lagged_data.index, pd.DatetimeIndex):
        lagged_data.index = pd.to_datetime(lagged_data.index)
    transformed_data = add_datetime_features(lagged_data)

    # Drop rows with missing values
    transformed_data.dropna(inplace=True)

    return transformed_data

# %%
def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    # msle = mean_squared_log_error(y_true, y_pred)
    return {
        'rmse': rmse,
    }

def perform_grid_search(model, param_grid, X_train, Y_train, cv):
    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        cv=cv,
        scoring='neg_mean_squared_error',
        verbose=3,
        n_jobs=-1,
    )
    grid_search.fit(X_train, Y_train)
    best_model = grid_search.best_estimator_
    cv_results = grid_search.cv_results_
    mean_score = -np.mean(cv_results['mean_test_score'])
    std_score = np.std(cv_results['mean_test_score'])
    
    # Take the square root of the mean_score and std_score
    rmse_mean = np.sqrt(mean_score)
    rmse_std = np.sqrt(std_score)
    
    return best_model, rmse_mean, rmse_std

def train_best_model(best_model, X_train, Y_train):
    best_model.fit(X_train, Y_train)
    return best_model

def predict(model, X):
    return model.predict(X)

def reshape_and_unscale_predictions(preds, actuals, scaler_Y):
    # Reshape predictions and actual values for unscaling
    preds_reshaped = preds.reshape(-1, 1)
    actuals_reshaped = actuals.values.reshape(-1, 1)

    # Unscale the predictions and actual values
    unscaled_preds, unscaled_actuals = unscale_data(preds_reshaped, actuals_reshaped, scaler_Y)

    # Convert the unscaled predictions and actuals back to pandas Series
    unscaled_preds_series = pd.Series(unscaled_preds.squeeze(), index=actuals.index)
    unscaled_actuals_series = pd.Series(unscaled_actuals.squeeze(), index=actuals.index)

    return unscaled_preds_series, unscaled_actuals_series

    
def create_directory_if_not_exists(directory):
    os.makedirs(directory, exist_ok=True)
    

def save_plots_for_experiment(experiment, hypothesis, model_name, train_or_test, plot_type):
    # Create the necessary directories
    experiment_path = os.path.join(experiment, hypothesis, train_or_test)
    create_directory_if_not_exists(experiment_path)
    
    # Return the save path
    save_path = os.path.join(experiment_path, f"{model_name}_{plot_type}.png")
    return save_path

    
def model_pipeline(model, param_grid, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, model_name,experiment, show_plot=False):

    # Perform grid search
    best_model, rmean_error_train, std_error = perform_grid_search(model, param_grid, X_train, Y_train, tscv)
    
    print("Best model:", best_model)
    print("Mean error:", rmean_error_train)
    print("Standard error:", std_error)
    
    # Train best model on all training data
    best_model_trained = train_best_model(best_model, X_train, Y_train)
    
    # Predict on train set
    train_preds = predict(best_model_trained, X_train)
    
    # Unscale and plot predictions vs actuals for train set
    unscaled_preds_series, unscaled_actuals_series = reshape_and_unscale_predictions(train_preds, Y_train, scaler_Y)
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "train", "predictions_vs_actuals")
    plot_series(unscaled_actuals_series, unscaled_preds_series, title="Unscaled Predictions vs Actual Training Data", save_path=save_path, show_plot=show_plot)

    # Perform residual analysis for train set
    residuals_train = unscaled_actuals_series - unscaled_preds_series
    print("Residual analysis for train set:")
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "train", "correlogram")
    plot_correlogram(residuals_train, save_path=save_path, show_plot=show_plot)
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "train", "homoskedasticity_plot")
    residual_analysis(residuals_train, unscaled_preds_series, save_path=save_path)
    print("Residuals quared\n")
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "train", "correlogram_squared")
    plot_correlogram(residuals_train.pow(2), save_path=save_path, show_plot=False)
    residual_analysis(residuals_train.pow(2), unscaled_preds_series.pow(2), save_path=None)
    
    # Predict on test set
    test_preds = predict(best_model_trained, X_test)
    rmse_test = np.sqrt(mean_squared_error(Y_test, test_preds))
    print("RMSE:", rmse_test)
    
    # Unscale and plot predictions vs actuals for test set
    unscaled_preds_series, unscaled_actuals_series = reshape_and_unscale_predictions(test_preds, Y_test, scaler_Y)
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "test", "predictions_vs_actuals")
    plot_series(unscaled_actuals_series, unscaled_preds_series, title="Unscaled Predictions vs Actual Test Data", save_path=save_path, show_plot=show_plot)

    # Perform residual analysis for test set
    residuals_test = unscaled_actuals_series - unscaled_preds_series
    print("Residual analysis for test set:")
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "test", "correlogram")
    plot_correlogram(residuals_test, save_path=save_path, show_plot=show_plot)
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "test", "homoskedasticity_plot")
    residual_analysis(residuals_test, unscaled_preds_series, save_path=save_path)
    print("Residuals quared\n")
    save_path = save_plots_for_experiment(experiment, hypothesis, model_name, "test", "correlogram_squared")
    plot_correlogram(residuals_test.pow(2), title='Residuals Squared', save_path=save_path, show_plot=False)
    residual_analysis(residuals_test.pow(2), unscaled_preds_series.pow(2), save_path=None)

    return best_model_trained , rmean_error_train, rmse_test

# %%
def plot_series(series1, series2, label1="Actual", label2="Predicted", title="Unscaled Predictions vs Actual Data", save_path=None, show_plot=False):
    fig, ax = plt.subplots()
    ax.plot(series1.index, series1, label=label1)
    ax.plot(series2.index, series2, label=label2, linestyle="--")
    ax.legend()
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.title(title)
    if save_path:
        plt.savefig(save_path)
    plt.close()

def plot_correlogram(x, lags=None, title=None,save_path=None, show_plot=False):
    lags = min(10, int(len(x)/5)) if lags is None else lags
    x = x + np.random.normal(0, 1e-10, len(x)) ## Add noise to avoid non-invertibility
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 8))
    
    # Residuals plot
    x.plot(ax=axes[0][0], title='Residuals')
    x.rolling(21).mean().plot(ax=axes[0][0], c='k', lw=1)
    q_p = np.max(q_stat(acf(x, nlags=lags), len(x))[1])
    stats = f'Q-Stat: {np.max(q_p):>8.2f}\nADF: {adfuller(x)[1]:>11.2f}'
    axes[0][0].text(x=.02, y=.85, s=stats, transform=axes[0][0].transAxes)
    
    # Probability plot
    probplot(x, plot=axes[0][1])
    mean, var, skew, kurtosis = moment(x, moment=[1, 2, 3, 4])
    s = f'Mean: {mean:>12.2f}\nSD: {np.sqrt(var):>16.2f}\nSkew: {skew:12.2f}\nKurtosis:{kurtosis:9.2f}'
    axes[0][1].text(x=.02, y=.75, s=s, transform=axes[0][1].transAxes)
    
    # ACF and PACF plots
    plot_acf(x=x, lags=lags, zero=False, ax=axes[1][0])
    plot_pacf(x, lags=lags, zero=False, ax=axes[1][1])
    axes[1][0].set_xlabel('Lag')
    axes[1][1].set_xlabel('Lag')
    
    fig.suptitle(title, fontsize=14)
    sns.despine()
    fig.tight_layout()
    fig.subplots_adjust(top=.9)
    if save_path:
        plt.savefig(save_path)
    plt.close()
    
    
def residual_analysis(residuals, y_pred, save_path=None):
    
    # Check for homoscedasticity
    print("Homoscedasticity scatter plot:")
    plt.scatter(y_pred, residuals)
    plt.xlabel("Predicted values")
    plt.ylabel("Residuals")
    plt.axhline(y=0, color="r", linestyle="--")
    if save_path:
        plt.savefig(save_path)
    plt.close()

    # Perform Ljung-Box test for autocorrelation in residuals
    lb_test = acorr_ljungbox(residuals, lags=[10], return_df=True)  
    print("Ljung-Box test for autocorrelation in residuals:")
    print(lb_test)
    # Assess the p-value of the Ljung-Box test
    p_value = lb_test['lb_pvalue'][10]
    if p_value < 0.05:
        print("The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).")
    else:
        print("The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).")
    
    # Perform Jarque-Bera test for normality in residuals
    jb_test = jarque_bera(residuals)
    print("\nJarque-Bera test for normality in residuals:")
    if jb_test[1] < 0.05:
        print(f"Test statistic: {jb_test[0]}, p-value: {jb_test[1]}")
        print("The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).")
    else:
        print(f"Test statistic: {jb_test[0]}, p-value: {jb_test[1]}")
        print("The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).")    
        
def plot_rmse_comparison(results, hypothesis, experiment):
    fig = plt.figure()
    model_names = list(results.keys())
    train_rmse_values = [result['train_rmse'] for result in results.values()]
    test_rmse_values = [result['test_rmse'] for result in results.values()]

    ind = np.arange(len(model_names))  # the x locations for the groups
    width = 0.35  # the width of the bars

    fig.suptitle('Algorithm Comparison')
    ax = fig.add_subplot(111)
    plt.bar(ind - width/2, train_rmse_values, width=width, label='Train Error')
    plt.bar(ind + width/2, test_rmse_values, width=width, label='Test Error')
    fig.set_size_inches(15, 8)
    plt.legend()
    ax.set_xticks(ind)
    ax.set_xticklabels(model_names)
    
    # Save the plot
    save_path = save_plots_for_experiment(experiment, hypothesis, "Results", "", "Model_Comparison")
    if save_path:
        plt.savefig(save_path)
    plt.close()

# %%
def evaluate_rw(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    msle = mean_squared_log_error(y_true, y_pred)

    return {
        'mae': mae,
        'mse': mse,
        'rmse': rmse,
        'mape': mape,
        'r2': r2,
        'msle': msle,
    }

# univaritae
## Simple models for benchmarking
def random_walk_forecast(start_point, forecast_length, return_mean, return_std, index):
    prediction = [start_point]

    for i in range(1, forecast_length):
        next_value = prediction[-1] * (1 + random.normalvariate(mu=return_mean, sigma=return_std))
        prediction.append(next_value)

    return pd.Series(prediction, index=index)

def calculate_benchmark_errors(series):
    mean_returns, std_returns = calculate_returns_stats(series)
    forecast_length = len(series)
    start_point = series[0]
    predictions = random_walk_forecast(start_point, forecast_length, mean_returns, std_returns, series.index)
    # print(predictions)
    evaluation_result = evaluate_rw(series, predictions)
    # Return a dictionary containing the evaluation results for each baseline
    return {
        'Benchmark MAE': evaluation_result['mae'],
        'Benchmark MSE': evaluation_result['mse'],
        'Benchmark RMSE': evaluation_result['rmse'],
        'Benchmark MAPE': evaluation_result['mape'],
        'Benchmark R2': evaluation_result['r2'],
        'Benchmark MSLE': evaluation_result['msle'],
    }

def calculate_returns_stats(time_series):
    # Calculate the returns
    returns = time_series / time_series.shift(1) - 1
    returns = returns.dropna()

    # Calculate mean returns and standard deviation of returns
    mean_returns = returns.mean()
    std_returns = returns.std()

    return mean_returns, std_returns

# multivariate
def random_walk_forecast_multivariate(start_points, forecast_length, return_means, return_stds, index):
    num_variables = len(start_points)
    predictions = [start_points]

    for _ in range(1, forecast_length):
        next_values = [predictions[-1][i] * (1 + random.normalvariate(mu=return_means[i], sigma=return_stds[i])) for i in range(num_variables)]
        predictions.append(next_values)

    # Transpose the list of predictions and convert each variable's predictions to a pandas Series
    predictions_transposed = list(map(list, zip(*predictions)))
    prediction_series = [pd.Series(pred, index=index) for pred in predictions_transposed]

    return prediction_series

def calculate_benchmark_errors_mult(series1, series2):
    mean_returns1, std_returns1 = calculate_returns_stats(series1)
    mean_returns2, std_returns2 = calculate_returns_stats(series2)
    
    forecast_length = len(series1)
    start_points = [series1[0], series2[0]]
    return_means = [mean_returns1, mean_returns2]
    return_stds = [std_returns1, std_returns2]
    
    predictions = random_walk_forecast_multivariate(start_points, forecast_length, return_means, return_stds, series1.index)
    
    evaluation_result1 = evaluate_rw(series1, predictions[0])
    evaluation_result2 = evaluate_rw(series2, predictions[1])
    # plot_time_series(series1, predictions[0])
    # plot_time_series(series2, predictions[1])
    
    return {
        'Series1 Benchmark MAE': evaluation_result1['mae'],
        'Series1 Benchmark MSE': evaluation_result1['mse'],
        'Series1 Benchmark RMSE': evaluation_result1['rmse'],
        'Series1 Benchmark MAPE': evaluation_result1['mape'],
        'Series1 Benchmark R2': evaluation_result1['r2'],
        'Series1 Benchmark MSLE': evaluation_result1['msle'],
        'Series2 Benchmark MAE': evaluation_result2['mae'],
        'Series2 Benchmark MSE': evaluation_result2['mse'],
        'Series2 Benchmark RMSE': evaluation_result2['rmse'],
        'Series2 Benchmark MAPE': evaluation_result2['mape'],
        'Series2 Benchmark R2': evaluation_result2['r2'],
        'Series2 Benchmark MSLE': evaluation_result2['msle'],
    }
    
def monte_carlo_simulation(series, n_trials=10000):
    # Initialize a dictionary to store the accumulated evaluation results
    accumulated_results = {
        'Benchmark MAE': 0,
        'Benchmark MSE': 0,
        'Benchmark RMSE': 0,
        'Benchmark MAPE': 0,
        'Benchmark R2': 0,
        'Benchmark MSLE': 0,
    }

    for _ in range(n_trials):
        # Calculate benchmark errors for this trial
        trial_results = calculate_benchmark_errors(series)

        # Accumulate the results of this trial
        for key in accumulated_results.keys():
            accumulated_results[key] += trial_results[key]

    # Average the accumulated results over the number of trials
    for key in accumulated_results.keys():
        accumulated_results[key] /= n_trials

    return accumulated_results
    
def monte_carlo_simulation_mult(series1, series2, n_trials=10000):
    # Initialize a dictionary to store the accumulated evaluation results
    accumulated_results = {
        'Series1 Benchmark MAE': 0,
        'Series1 Benchmark MSE': 0,
        'Series1 Benchmark RMSE': 0,
        'Series1 Benchmark MAPE': 0,
        'Series1 Benchmark R2': 0,
        'Series1 Benchmark MSLE': 0,
        'Series2 Benchmark MAE': 0,
        'Series2 Benchmark MSE': 0,
        'Series2 Benchmark RMSE': 0,
        'Series2 Benchmark MAPE': 0,
        'Series2 Benchmark R2': 0,
        'Series2 Benchmark MSLE': 0,
    }

    for _ in range(n_trials):
        # Calculate benchmark errors for this trial
        trial_results = calculate_benchmark_errors_mult(series1, series2)

        # Accumulate the results of this trial
        for key in accumulated_results.keys():
            accumulated_results[key] += trial_results[key]

    # Average the accumulated results over the number of trials
    for key in accumulated_results.keys():
        accumulated_results[key] /= n_trials

    return accumulated_results

# %% [markdown]
# Benchmark

# %%
df = load_raw_data("Test_data.csv")
raw_hourly = df.resample('H').mean()
raw_ts_1_hourly = raw_hourly['ts1'].dropna()
raw_ts_2_hourly = raw_hourly['ts2'].dropna()
# Run the Monte Carlo simulation on your time series data
print('Univariate')
average_results = monte_carlo_simulation(raw_ts_1_hourly, n_trials=1000)
print(average_results)
average_results = monte_carlo_simulation(raw_ts_2_hourly, n_trials=1000)
print(average_results)
print('Multivariate')
# Run the Monte Carlo simulation on your time series data
average_results = monte_carlo_simulation_mult(raw_ts_1_hourly, raw_ts_2_hourly)
print(average_results)

# %%
models_and_param_grids = [
    {
        'model': DecisionTreeRegressor(random_state=42),
        'param_grid': {
            'max_depth': [None, 10, 20, 30,50,150],
            'min_samples_split': [2, 5, 10],
            'max_features': ['auto'],
            'min_samples_leaf': [1, 3, 5, 10]
        },
        'model_name': 'CART',
    },
    # {
    #     'model': MLPRegressor(random_state=42),
    #     'param_grid': {
    #         'hidden_layer_sizes': [(50,), (100,), (50, 50),(100, 100), (50, 50, 50), (100, 100, 100), (50, 50, 50, 50), (100, 100, 100, 100)],
    #         'activation': ['tanh', 'relu', 'logistic'],
    #         'solver': ['sgd'],
    #         'alpha': [0.00005, 0.0005, 0.005],
    #         'early_stopping': [True],
    #         'max_iter': [600],
    #         'shuffle': [False],
    #     },
    #     'model_name': 'MLP',
    # },
    {
        'model': KNeighborsRegressor(),
        'param_grid': {
            'n_neighbors': [3, 5, 7, 9, 11],
            'weights': ['uniform', 'distance'],
            'algorithm': ['auto'],
            'leaf_size': [10, 30, 50],
        },
        'model_name': 'KNN',
    },
    # {
    #     'model': GaussianProcessRegressor(random_state=42),
    #     'param_grid': {
    #         'kernel': [RBF()],
    #         'alpha': [1e-5, 1e-2],
    #         'n_restarts_optimizer': [0, 1, 3],
    #     },
    #     'model_name': 'GPR',
    # },
    {
        'model': lgb.LGBMRegressor(n_estimators=100, learning_rate=0.1, max_depth=-1, random_state=42),
        'param_grid': {
            'lgbmregressor__n_estimators': [100,200],
            'lgbmregressor__learning_rate': [0.01],
            'lgbmregressor__max_depth': [5, 10, 20],
            'lgbmregressor__num_leaves': [35, 50],
        },
        'model_name': 'GBR',
    },
        {
        'model': xgb.XGBRegressor(random_state=42),
        'param_grid': {
            'n_estimators': [100,200],
            'learning_rate': [0.01, 0.1],
            'max_depth': [3, 4, 5],
            'min_child_weight': [1, 3, 5],
        },
        'model_name': 'XGB',
    }
]

# %%
def run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment):
    results = {}

    for model_info in models_and_param_grids:
        model = model_info['model']
        param_grid = model_info['param_grid']
        model_name = model_info['model_name']
        print(f"\nTraining {model_name} model...")

        best_model_trained, train_rmse, test_rmse = model_pipeline(
            model, param_grid, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, model_name, experiment=experiment
        )

        results[model_name] = {
            'model': best_model_trained,
            'train_rmse': train_rmse,
            'test_rmse': test_rmse,
        }

    print("\nResults:")
    for model_name, model_results in results.items():
        print(
            f"{model_name}: Train RMSE: {model_results['train_rmse']:.4f}, Test RMSE: {model_results['test_rmse']:.4f}"
        )

    plot_rmse_comparison(results, hypothesis, experiment=experiment)

    return results

# %% [markdown]
# Experiments

# %%
# # Specify the datetime to split the Series
# split_date = pd.Timestamp('2020-01-05')

# # Split the Series into two parts
# before_split = s.loc[s.index <= split_date]
# after_split = s.loc[s.index > split_date]

# print("Before split:")
# print(before_split)
# print("\nAfter split:")
# print(after_split)

# %%
test_size = 24
n_splits = 30
tscv = TimeSeriesSplit(n_splits=n_splits, test_size=test_size)
lags = 4
# # 1. Split train/test
# # train_data, test_data = train_test_split(raw_rt_daily, test_size=0.2, shuffle=False)
# train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
# #set up data for supervised learning for H1: ts1 pred ts1
# train_transformed = prepare_time_series_data(train_data, 'ts1', lags)
# test_transformed = prepare_time_series_data(test_data, 'ts1', lags)
# train_transformed

# %% [markdown]
# Experiment 1 Raw NO

# %%
def load_raw_data(filename):
    raw_df = pd.read_csv(filename, header=None)
    raw_df.columns = ['datetime', 'ts1', 'ts2']
    raw_df['datetime'] = pd.to_datetime(raw_df['datetime'] - 719529, unit='d').round('s')
    raw_df.set_index('datetime', inplace=True)
    raw_df.dropna(inplace=True)
    return raw_df

def calculate_log_returns(df):
    rt = np.log(df / df.shift(1))
    rt.dropna(inplace=True)
    return rt

#load raw data
df = load_raw_data("Test_data.csv")
#calcualte log returns
raw_rt = calculate_log_returns(df)
raw_rt_daily = raw_rt.resample('H').mean()

# %%
  def load_clean_data(filename):
    clean_df = pd.read_csv(filename)
    clean_df.columns = ['datetime', 'ts1', 'ts2']
    clean_df.set_index('datetime', inplace=True)
    clean_df.index = pd.to_datetime(clean_df.index)
    return clean_df     

df = load_clean_data('interpolate_clean_df.csv')
#calcualte log returns
imp_rt = calculate_log_returns(df)
rt_d = imp_rt.resample('H').mean()

# %%
raw_rt_daily.columns = ['ts1', 'ts2']
raw_rt_daily.isna().sum()
# Out:
# ts1    17864
# ts2    17864
# dtype: int64

# %%
# imp_rt_daily = pd.read_csv('rt_daily.csv')
# rt_d.columns = ['datetime', 'ts1', 'ts2']
# rt_d.set_index('datetime', inplace = True)
# rt_d

# %%
hypothesis_results = {}

# %%
# 1. Split train/test
# train_data, test_data = train_test_split(raw_rt_daily, test_size=0.2, shuffle=False)
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')


hypothesis = 'H1'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_no_outliers'

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_leaf=10,
#                       random_state=42)
# Mean error: 0.06494149379038984
# Standard error: 0.026633423610974486
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.875495   0.001305
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 13578.409001966358, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  47.490456  7.687857e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 4430764.035327522, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.044053787997099594
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  26.140109   0.003556
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2062.200746294769, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  9.270484   0.506641
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1776388.8570748565, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=50, n_neighbors=9)
# Mean error: 0.056965650377524234
# Standard error: 0.011872229822321497
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat     lb_pvalue
# 10  50.76582  1.929056e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 20709.96852505241, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  45.511501   0.000002
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 8381798.685377244, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.0445652175444922
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  11.162627   0.344989
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1491.230732967468, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10  7.35616   0.691448
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2118353.0217865617, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.05620168917625283
# Standard error: 0.0
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  32.810591   0.000293
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 11545.033426528042, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  17.483078   0.064335
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6603080.4715938335, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.044996648595316144
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.061881   0.020666
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1918.0519296111045, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  11.078384   0.351444
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2660653.2672188156, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.057992643480633904
# Standard error: 0.019742508292277364
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  29.974631   0.000865
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 15077.675361819429, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  33.679522   0.000209
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7583386.301460819, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04277091574895933
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  26.422232   0.003212
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2401.876854687745, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.355419   0.594163
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2330291.8087774157, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0649, Test RMSE: 0.0441
# KNN: Train RMSE: 0.0570, Test RMSE: 0.0446
# GBR: Train RMSE: 0.0562, Test RMSE: 0.0450
# XGB: Train RMSE: 0.0580, Test RMSE: 0.0428

# %%
# 1. Split train/test
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')

hypothesis = 'H2'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_no_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_split=5,
#                       random_state=42)
# Mean error: 0.03152022350174451
# Standard error: 0.01603319211208599
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  24.112073   0.007308
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 40259.7896907649, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  56.482472  1.667013e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5792986.318362259, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.019881514136146267
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.699065   0.023293
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 66437.47863240296, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.733759   0.004115
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6705159.058292511, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=7)
# Mean error: 0.026302390070934406
# Standard error: 0.0036736743497050614
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  16.379602   0.089269
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 161552.67046154433, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  294.174406  2.647391e-57
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 77820261.87391911, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.020752157267612998
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  10.234039   0.420206
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 63313.89266621609, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  17.004404   0.074267
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6707061.518102358, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.02723683120804812
# Standard error: 0.0
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  16.973754   0.074947
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 384983.2327894624, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  81.181618  2.944199e-13
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 395413884.799104, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.020460511305701073
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  13.206167   0.212372
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 22213.534750349532, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  11.458088   0.322959
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 3164441.2628200985, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.038174905014657555
# Standard error: 0.03423261421555406
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  12.334182   0.263313
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 42737.797416713816, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  72.484584  1.465719e-11
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6688428.297317286, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.019338708532220934
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.014133   0.029119
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 64504.912504145475, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.650238    0.00424
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6632195.533438214, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0315, Test RMSE: 0.0199
# KNN: Train RMSE: 0.0263, Test RMSE: 0.0208
# GBR: Train RMSE: 0.0272, Test RMSE: 0.0205
# XGB: Train RMSE: 0.0382, Test RMSE: 0.0193

# %%
# 1. Split train/test
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')


hypothesis = 'H3'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_no_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_split=10,
#                       random_state=42)
# Mean error: 0.06393307276810109
# Standard error: 0.026006815066512205
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.906338   0.015589
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 13335.077316355819, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  41.865895   0.000008
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 3246486.7542484957, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04594417827402462
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  29.022781   0.001236
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2477.9254827745312, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  7.820656    0.64635
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 655220.3502486416, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.056967057933715405
# Standard error: 0.011453354701840562
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  55.035562  3.110127e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 22747.993407746253, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  39.660835   0.000019
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 8995770.53624515, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04390865531333866
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10  8.86116   0.545329
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1770.3191082533735, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  7.629055   0.665019
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2559971.5756405164, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.05615936727129682
# Standard error: 6.585445079827193e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  32.650026   0.000312
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 9668.363741531692, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.492419   0.009068
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5495181.1261333, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04470482364436514
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  15.105005    0.12828
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1607.273281126362, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  9.352149   0.499041
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1580991.5561803079, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.05823935914521817
# Standard error: 0.019132927108269644
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.767204   0.001359
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 10638.303215432677, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  43.668002   0.000004
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2780371.6228316, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.043450718182238494
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  22.534285   0.012602
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2426.6889013452137, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.522455   0.577942
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1463641.8888721182, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0639, Test RMSE: 0.0459
# KNN: Train RMSE: 0.0570, Test RMSE: 0.0439
# GBR: Train RMSE: 0.0562, Test RMSE: 0.0447
# XGB: Train RMSE: 0.0582, Test RMSE: 0.0435

# %%
# 1. Split train/test
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')


hypothesis = 'H4'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_no_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_leaf=10,
#                       random_state=42)
# Mean error: 0.03379855770303175
# Standard error: 0.017506697741034024
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  6.902948   0.734574
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 184387.70749919876, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  109.246374  7.570515e-19
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 109909372.54491143, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.02053860634208304
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  20.98784   0.021179
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 65047.708775350206, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  27.55827   0.002124
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6007442.100061528, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=9, weights='distance')
# Mean error: 0.02652225542920788
# Standard error: 0.0043307033417356
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# RMSE: 0.02093902596752031
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  14.972484   0.133068
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 60716.62368068622, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  14.195341   0.164267
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7500848.136375831, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.029756599593829595
# Standard error: 3.2927225399135965e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  13.153664   0.215207
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 544797.2212943301, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  54.012031  4.827289e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 366179115.7234955, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.021263002505776143
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  19.495802   0.034399
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 30005.61359751767, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.545954   0.004401
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 4193469.641331838, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.03928656258590205
# Standard error: 0.0338682883464647
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  6.382233   0.782193
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 54480.76830710311, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  43.22852   0.000005
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7073992.236186546, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.020004970177921515
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  18.948665    0.04092
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 50209.0683541339, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.631535   0.004269
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 4013294.906354319, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0338, Test RMSE: 0.0205
# KNN: Train RMSE: 0.0265, Test RMSE: 0.0209
# GBR: Train RMSE: 0.0298, Test RMSE: 0.0213
# XGB: Train RMSE: 0.0393, Test RMSE: 0.0200

# %% [markdown]
# Experiment 2 Raw WO

# %%
# def standardize_series(series):
#     return StandardScaler().fit_transform(series.values.reshape(-1, 1))

# def apply_dbscan_clustering(series_standardized, eps=0.5, min_samples=2):
#     dbscan = DBSCAN(eps=eps, min_samples=min_samples)
#     return dbscan.fit_predict(series_standardized)

# def extract_outliers_from_clusters(series, clusters):
#     """Identify the outliers (cluster label -1 indicates an outlier)"""
#     return series[clusters == -1]

# def cluster_based_outlier_detection(series):
#     series_standardized = standardize_series(series)
#     clusters = apply_dbscan_clustering(series_standardized, eps=0.15)
#     outliers = extract_outliers_from_clusters(series, clusters)
#     print('Outliers shape: {}'.format(outliers.shape))
#     # Create a DataFrame with the same index as the original series
#     outliers_df = pd.DataFrame(index=series.index)
#     outliers_df['outliers'] = 0
#     outliers_df.loc[outliers.index, 'outliers'] = 1

#     return outliers_df
    
# def prepare_time_series_data(df, var, max_lag, detect_outliers=False):
#     # Generate lagged features
#     lagged_data = generate_lagged_features(df, var, max_lag)
#     # print('Lagged data shape: {}'.format(lagged_data.shape))
    
#     # Add outlier features if detect_outliers is True
#     if detect_outliers:
#         series = df[var].pow(2)
#         series.dropna(inplace=True)  
#         # print('Series shape: {}'.format(series.shape))
#         outliers_df = cluster_based_outlier_detection(series)
#         # print('Outliers DataFrame shape: {}'.format(outliers_df.shape))
#         lagged_outliers = generate_lagged_features(outliers_df, 'outliers', max_lag)
#         # print('Lagged outliers shape: {}'.format(lagged_outliers.shape))
#         lagged_data = lagged_data.merge(lagged_outliers, left_index=True, right_index=True)
#         # print('Lagged data shape: {}'.format(lagged_data.shape))

#     # Add datetime features
#     if not isinstance(lagged_data.index, pd.DatetimeIndex):
#         lagged_data.index = pd.to_datetime(lagged_data.index)
#     transformed_data = add_datetime_features(lagged_data)

#     # Drop rows with missing values
#     transformed_data.dropna(inplace=True)

#     return transformed_data

# %%
rt_1 = train_data['ts1']
squared_rt2 = rt_1.pow(2).dropna()

# Perform cluster-based outlier detection for both series
outliers_rt1 = cluster_based_outlier_detection(squared_rt2)
outliers_rt1[outliers_rt1['outliers'] == 1]

# Plot the original series rt_1
plt.figure(figsize=(12, 6))
plt.plot(rt_1, label='rt_1')

# Get the indices and values of the outliers
outlier_indices = outliers_rt1[outliers_rt1['outliers'] == 1].index
outlier_values = rt_1.loc[outlier_indices]

# Plot the outliers as red dots
plt.scatter(outlier_indices, outlier_values, color='red', label='Outliers')

# Customize the plot
plt.xlabel('Date')
plt.ylabel('Return')
plt.title('Return Series with Outliers')
plt.legend()

# Show the plot
plt.show()
# Out:
# Outliers shape: (17,)

# %%
# 1. Split train/test
# train_data, test_data = train_test_split(raw_rt_daily, test_size=0.2, shuffle=False)
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags, detect_outliers=True)
# train_transformed = prepare_time_series_data(train_data, 'ts1_raw', lags)
# test_transformed = prepare_time_series_data(test_data, 'ts1_raw', lags)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')

hypothesis = 'H1' +"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_outliers'

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (17,)
# Outliers shape: (3,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_leaf=10,
#                       random_state=42)
# Mean error: 0.06461036725326026
# Standard error: 0.025747729199576002
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.875495   0.001305
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 13578.409001966345, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  47.490456  7.687857e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 4430764.035327522, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.0440537879970996
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  26.140109   0.003556
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2062.2007462947695, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  9.270484   0.506641
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1776388.8570748623, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=9)
# Mean error: 0.0569602830647401
# Standard error: 0.012022976395915064
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  50.916066  1.809823e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 20682.43554861831, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  45.702883   0.000002
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 8376927.39739453, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.044500547427230565
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  11.088375   0.350674
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1501.3595512997092, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  6.899011   0.734943
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2149307.7595725, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.05620168917625283
# Standard error: 0.0
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  32.810591   0.000293
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 11545.033426528042, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  17.483078   0.064335
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6603080.4715938335, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.044996648595316144
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.061881   0.020666
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1918.0519296111045, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  11.078384   0.351444
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2660653.2672188156, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.05786223920759365
# Standard error: 0.01984870801193512
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  29.974631   0.000865
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 15077.675361819429, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  33.679522   0.000209
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7583386.301460819, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04277091574895933
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  26.422232   0.003212
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2401.876854687745, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.355419   0.594163
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2330291.8087774157, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0646, Test RMSE: 0.0441
# KNN: Train RMSE: 0.0570, Test RMSE: 0.0445
# GBR: Train RMSE: 0.0562, Test RMSE: 0.0450
# XGB: Train RMSE: 0.0579, Test RMSE: 0.0428

# %%
# 1. Split train/test
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags, detect_outliers=True)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')

hypothesis = 'H2'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (24,)
# Outliers shape: (9,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_leaf=10,
#                       random_state=42)
# Mean error: 0.03128047449341169
# Standard error: 0.01578086441854199
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  9.038864   0.528419
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 182969.955554585, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  129.761559  5.224821e-23
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 114156352.01388013, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.019860080410343258
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  24.552829   0.006261
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 54205.914559430894, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  36.296597   0.000075
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5867862.650255179, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=7)
# Mean error: 0.026302390070934406
# Standard error: 0.0036736743497050614
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  13.347045    0.20491
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 167653.9038729229, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  257.857871  1.206821e-49
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 77386272.66525136, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.020752157267612998
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  10.234039   0.420206
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 63313.89266621609, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  17.004404   0.074267
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6707061.518102358, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.02723683120804812
# Standard error: 0.0
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  16.973754   0.074947
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 384983.2327894624, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  81.181618  2.944199e-13
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 395413884.799104, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.020460511305701073
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  13.206167   0.212372
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 22213.534750349532, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  11.458088   0.322959
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 3164441.2628200985, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.03819888727003886
# Standard error: 0.03423314603034724
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  12.334182   0.263313
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 42737.797416713816, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  72.484584  1.465719e-11
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6688428.297317286, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.019338708532220934
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.014133   0.029119
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 64504.912504145475, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.650238    0.00424
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6632195.533438214, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0313, Test RMSE: 0.0199
# KNN: Train RMSE: 0.0263, Test RMSE: 0.0208
# GBR: Train RMSE: 0.0272, Test RMSE: 0.0205
# XGB: Train RMSE: 0.0382, Test RMSE: 0.0193

# %%
# 1. Split train/test
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags, detect_outliers=True)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')


hypothesis = 'H3'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (17,)
# Outliers shape: (3,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_split=10,
#                       random_state=42)
# Mean error: 0.06433903712761892
# Standard error: 0.026930330673406735
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  22.182184   0.014203
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 9705.619828600733, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  44.117268   0.000003
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1969201.8671639524, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04736921389183928
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  30.667339   0.000666
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 4224.539549385798, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  13.513111    0.19638
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 791469.7313209899, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.05693795913865152
# Standard error: 0.011455383683797934
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  56.706999  1.512918e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 22772.097577497156, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  39.795345   0.000018
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 9008957.081711235, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04385553531513684
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.763701   0.554667
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1781.3367460599604, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  7.156705   0.710573
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2588960.5704641617, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.05615936727129682
# Standard error: 6.585445079827193e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  32.650026   0.000312
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 9668.363741531692, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.492419   0.009068
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5495181.1261333, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04470482364436514
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  15.105005    0.12828
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1607.273281126362, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  9.352149   0.499041
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1580991.5561803079, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.05818749238869127
# Standard error: 0.019202669972831116
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.767204   0.001359
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 10638.303215432677, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  43.668002   0.000004
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2780371.6228316, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.043450718182238494
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  22.534285   0.012602
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2426.6889013452137, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.522455   0.577942
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1463641.8888721182, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0643, Test RMSE: 0.0474
# KNN: Train RMSE: 0.0569, Test RMSE: 0.0439
# GBR: Train RMSE: 0.0562, Test RMSE: 0.0447
# XGB: Train RMSE: 0.0582, Test RMSE: 0.0435

# %%
# 1. Split train/test
train_data, test_data = raw_rt_daily.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags, detect_outliers=True)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')


hypothesis = 'H4'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Raw_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (24,)
# Outliers shape: (9,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_split=10,
#                       random_state=42)
# Mean error: 0.031856525005108764
# Standard error: 0.01351419353870361
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  16.472298   0.086887
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 36501.45311039232, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  67.043622  1.644725e-10
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 4488983.765587681, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.04398281938739982
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.925941   0.539146
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 3465139.4591612658, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  0.177574        1.0
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7549361.090722802, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=9, weights='distance')
# Mean error: 0.02652225542920788
# Standard error: 0.0043307033417356
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# RMSE: 0.020934808441287516
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  14.968804   0.133203
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 60420.492638311676, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  14.230133   0.162751
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7467060.735734148, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.029756599593829595
# Standard error: 3.2927225399135965e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  13.153664   0.215207
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 544797.2212943301, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  54.012031  4.827289e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 366179115.7234955, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.021263002505776143
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  19.495802   0.034399
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 30005.61359751767, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.545954   0.004401
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 4193469.641331838, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.03921514382812021
# Standard error: 0.033938509502416996
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  7.824919   0.645934
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 28356.11469724438, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  38.28911   0.000034
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6829141.998411182, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.040311188774455005
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  11.201173   0.342061
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2861717.572764803, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  0.288176        1.0
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7510536.067105058, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0319, Test RMSE: 0.0440
# KNN: Train RMSE: 0.0265, Test RMSE: 0.0209
# GBR: Train RMSE: 0.0298, Test RMSE: 0.0213
# XGB: Train RMSE: 0.0392, Test RMSE: 0.0403

# %% [markdown]
# Experiment 3 Imp NO

# %%
# 1. Split train/test rt_d.iloc[:int(len(raw_rt_daily)*0.8), :]
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')


hypothesis = 'H1'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Imputed_no_outliers'

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_leaf=10,
#                       random_state=42)
# Mean error: 0.012367162769355193
# Standard error: 0.006145371916050096
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  51.621599  1.340714e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 85281729.71301645, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  157.242233  1.201165e-28
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 617395575232.2283, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06491004545244027
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  22.571559   0.012443
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2253.361578769402, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.603177   0.570131
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2094294.9935038858, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.01301833193861847
# Standard error: 0.004911363229602802
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  116.771963  2.283338e-20
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 130546276.66201203, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  224.415346  1.271525e-42
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 690976573186.563, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06356079437278109
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.502472    0.00447
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2742.574246670357, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.485093   0.581564
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2284381.50286469, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.010844969023831278
# Standard error: 1.1641532182693481e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  54.150348  4.549204e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 116597904.31740393, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  65.100224  3.878235e-10
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 760392032624.1954, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06390495260228826
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  25.85172   0.003945
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2516.44604213484, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.282725   0.601242
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2023363.7744051386, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.053730650091616275
# Standard error: 0.06381635703805658
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  41.574224   0.000009
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 47658302.503392085, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  179.61019  2.822884e-33
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 643654771911.3346, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06558326665632129
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.739061   0.016491
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2269.195801898788, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  7.799496   0.648415
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1787921.4228223457, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0124, Test RMSE: 0.0649
# KNN: Train RMSE: 0.0130, Test RMSE: 0.0636
# GBR: Train RMSE: 0.0108, Test RMSE: 0.0639
# XGB: Train RMSE: 0.0537, Test RMSE: 0.0656

# %%
# 1. Split train/test
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')

hypothesis = 'H2'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Imputed_no_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=20, max_features='auto', random_state=42)
# Mean error: 0.02330836048810462
# Standard error: 0.013013876358242568
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.806663   0.001339
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1283756.0284787377, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  2001.412781        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 77801687975.94958, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.14810484679415495
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.085142   0.020508
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 41470.33649744646, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  17.969183   0.055486
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5017913.478866003, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.021334877017688544
# Standard error: 0.004325322176841728
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  263.768217  6.875264e-51
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1236628.0641962977, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  8436.266928        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 17532239518.06231, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.13358563847641403
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.414215    0.02557
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 74512.45993550055, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  24.867194   0.005603
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5896383.4828708405, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.01999528502764812
# Standard error: 2.3283064365386963e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  54.885597  3.317318e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1118319.519112879, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  4433.564477        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 35644016220.590355, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.1342748245738944
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.629275   0.023832
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 71469.784494144, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.889856   0.003891
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5464898.943477055, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.027613882174907352
# Standard error: 0.0235333865438839
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  38.798929   0.000028
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1265798.7262175176, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  4998.144671        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 42659609577.679504, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.1330852694687273
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  19.853166   0.030672
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 72835.53789156004, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  29.625013   0.000986
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6605651.637491465, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0233, Test RMSE: 0.1481
# KNN: Train RMSE: 0.0213, Test RMSE: 0.1336
# GBR: Train RMSE: 0.0200, Test RMSE: 0.1343
# XGB: Train RMSE: 0.0276, Test RMSE: 0.1331

# %%
# 1. Split train/test
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')


hypothesis = 'H3'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Imputed_no_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_leaf=3,
#                       random_state=42)
# Mean error: 0.012983588941673115
# Standard error: 0.0072942172821315356
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  70.294833  3.888963e-11
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 29876589.131665803, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  259.109911  6.578309e-50
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 118044929022.86191, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06524689928176045
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.413145    0.00932
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2204.3994861130827, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  7.284182   0.698372
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2097496.6619197843, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.013324353624691138
# Standard error: 0.004982166798160934
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  170.676884  2.008843e-31
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 123109357.34374301, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  243.901026  1.038603e-46
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 693677338112.9352, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06378770475696188
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.877557   0.003908
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2729.028916352157, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10  8.51085   0.579067
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2265891.149354073, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.010711334802916136
# Standard error: 1.6463612699567982e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  48.770098  4.488005e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 101474230.36112283, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  79.293388  6.905203e-13
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 600332651470.7258, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06376634007901771
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.007106   0.001801
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2551.4701637433927, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.257211   0.603729
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1893086.5036836544, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.053733239297829
# Standard error: 0.06381531075642088
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  34.874392   0.000131
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 177486136.7579129, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  43.327987   0.000004
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1036574152281.6722, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06507851160790391
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.093855   0.010405
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2625.2655261112072, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.364754   0.593255
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1623045.8480706813, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0130, Test RMSE: 0.0652
# KNN: Train RMSE: 0.0133, Test RMSE: 0.0638
# GBR: Train RMSE: 0.0107, Test RMSE: 0.0638
# XGB: Train RMSE: 0.0537, Test RMSE: 0.0651

# %%
# 1. Split train/test
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')


hypothesis = 'H4'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Imputed_no_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_split=10,
#                       random_state=42)
# Mean error: 0.02377308996967461
# Standard error: 0.013622040299621028
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  37.306694    0.00005
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1381371.4261546277, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  4237.200254        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 36934721307.197716, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.138615507102161
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.810821   0.016098
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 65493.86528766163, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.079837   0.010456
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6735558.667706211, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.021111756927055258
# Standard error: 0.004679053183780234
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  296.105172  1.034770e-57
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1166119.7139289244, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  8834.221433        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 17541468198.669193, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.13365419464175549
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.127326   0.028071
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 72735.76179528821, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  24.612009   0.006132
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5684568.090729141, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.019862816504109197
# Standard error: 3.2927225399135965e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  49.672327  3.066103e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 880080.3270883018, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  6061.560607        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 12873302945.72244, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.13450493781637787
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  22.423951   0.013085
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 82463.60042105947, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10  22.6162   0.012255
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6347350.32096513, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.027669416990167662
# Standard error: 0.02347393531279228
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  40.453405   0.000014
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 515827.39611143206, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#          lb_stat  lb_pvalue
# 10  10501.121909        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2071080896.7513525, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.13732279285009508
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.449363   0.018169
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 69795.68900305856, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  24.69303   0.005959
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7496470.677978009, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0238, Test RMSE: 0.1386
# KNN: Train RMSE: 0.0211, Test RMSE: 0.1337
# GBR: Train RMSE: 0.0199, Test RMSE: 0.1345
# XGB: Train RMSE: 0.0277, Test RMSE: 0.1373

# %% [markdown]
# Experiment 4 Imputed WO

# %%
# 1. Split train/test rt_d.iloc[:int(len(raw_rt_daily)*0.8), :]
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags, detect_outliers=True)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')


hypothesis = 'H1'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Impute_outliers'

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (12,)
# Outliers shape: (3,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_split=5,
#                       random_state=42)
# Mean error: 0.0124318724226431
# Standard error: 0.006538351976230503
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  30.187022   0.000798
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1423754.1533878597, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  2217.675942        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1200417057.2654824, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06837117104974158
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.729722   0.004121
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1854.9753729986742, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  14.063145   0.170131
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1285368.343918769, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.013024465215606377
# Standard error: 0.004906006474081415
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  109.246139  7.571342e-19
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 81447860.93634744, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  72.134259  1.713767e-11
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 387538716859.5841, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06358863387578255
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.653005   0.004236
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2734.0179282912927, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.536809   0.576552
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2282416.8156577996, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.010844969023831278
# Standard error: 1.1641532182693481e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  54.150348  4.549204e-08
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 116597904.31740393, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  65.100224  3.878235e-10
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 760392032624.1954, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06390495260228826
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  25.85172   0.003945
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2516.44604213484, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.282725   0.601242
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2023363.7744051386, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.05370964548525792
# Standard error: 0.06379752101449775
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.771028   0.001357
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1009994.2740643458, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  2637.144731        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 383474187.1372596, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06429054801270921
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.400043   0.009362
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2469.580377265089, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  7.598683   0.667972
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2039603.5181689651, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0124, Test RMSE: 0.0684
# KNN: Train RMSE: 0.0130, Test RMSE: 0.0636
# GBR: Train RMSE: 0.0108, Test RMSE: 0.0639
# XGB: Train RMSE: 0.0537, Test RMSE: 0.0643

# %%
# 1. Split train/test rt_d.iloc[:int(len(raw_rt_daily)*0.8), :]
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags, detect_outliers=True)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')

hypothesis = 'H2'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Impute_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (21,)
# Outliers shape: (9,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=20, max_features='auto', min_samples_split=10,
#                       random_state=42)
# Mean error: 0.02351333993189478
# Standard error: 0.015271755244530847
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.325546    0.02632
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 396733.45248727914, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  3499.114103        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 46540499048.11512, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.14225240708577644
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  18.985556   0.040447
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 53760.181686432275, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.609244   0.017224
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6525658.355503444, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11, weights='distance')
# Mean error: 0.02032311893782692
# Standard error: 0.0030412987971826146
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# RMSE: 0.13404324640777804
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.147105   0.027892
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 74219.67039448861, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  25.149501   0.005069
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5646405.482653589, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.01998866299669144
# Standard error: 0.0
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  48.235827  5.620613e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1186722.6317129761, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  4961.6542        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 28888784580.66063, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.13459659599225185
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  19.434117   0.035083
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 74890.80169335431, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  24.930854   0.005478
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5420197.554632322, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.0296619919314785
# Standard error: 0.02221942046619031
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  29.141224   0.001182
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 319408.53608171316, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#          lb_stat  lb_pvalue
# 10  10797.560559        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1625440321.6615639, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.13318779111406792
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  19.540387   0.033912
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 59730.6890055058, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10  32.7429   0.000301
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5248439.1834693095, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0235, Test RMSE: 0.1423
# KNN: Train RMSE: 0.0203, Test RMSE: 0.1340
# GBR: Train RMSE: 0.0200, Test RMSE: 0.1346
# XGB: Train RMSE: 0.0297, Test RMSE: 0.1332

# %%
# 1. Split train/test rt_d.iloc[:int(len(raw_rt_daily)*0.8), :]
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts1', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts1', lags, detect_outliers=True)
train_transformed = train_transformed.drop(['ts1'], axis=1)
test_transformed = test_transformed.drop(['ts1'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts2')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts2')
X_test, Y_test = extract_column(test_data_df, 'ts2')


hypothesis = 'H3'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Impute_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (12,)
# Outliers shape: (3,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', random_state=42)
# Mean error: 0.01297851793437528
# Standard error: 0.006993864363263523
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.591105   0.008763
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1392317.9434444348, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  2057.971094        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1153255695.2172742, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06809283676755537
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  22.091641   0.014644
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2032.4569834521133, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  9.654101   0.471346
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1222535.0567062744, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=11)
# Mean error: 0.013324353624691138
# Standard error: 0.004982166798160934
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat     lb_pvalue
# 10  127.707586  1.370290e-22
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 81305827.49258816, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  70.160166  4.129006e-11
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 387567281305.96204, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06379810811992813
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  26.012596   0.003723
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2724.334619045497, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10  8.51221   0.578935
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2267416.189092561, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.010711334802916136
# Standard error: 1.6463612699567982e-10
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  48.770098  4.488005e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 101474230.36112283, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  79.293388  6.905203e-13
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 600332651470.7258, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.06376634007901771
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.007106   0.001801
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2551.4701637433927, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.257211   0.603729
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1893086.5036836544, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.053709180874277604
# Standard error: 0.06379768612359274
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  31.773355   0.000437
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1321126.1154657458, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat  lb_pvalue
# 10  2723.13313        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 676802585.9759805, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.0643483730510074
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  23.843276   0.008027
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2565.310422916382, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  8.257127   0.603737
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 2038167.9004103702, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0130, Test RMSE: 0.0681
# KNN: Train RMSE: 0.0133, Test RMSE: 0.0638
# GBR: Train RMSE: 0.0107, Test RMSE: 0.0638
# XGB: Train RMSE: 0.0537, Test RMSE: 0.0643

# %%
# 1. Split train/test rt_d.iloc[:int(len(raw_rt_daily)*0.8), :]
train_data, test_data = rt_d.iloc[:int(len(raw_rt_daily)*0.8), :], raw_rt_daily.iloc[int(len(raw_rt_daily)*0.8):, :]
#set up data for supervised learning for H1: ts1 pred ts1
train_transformed = prepare_time_series_data(train_data, 'ts2', lags, detect_outliers=True)
test_transformed = prepare_time_series_data(test_data, 'ts2', lags, detect_outliers=True)
train_transformed = train_transformed.drop(['ts2'], axis=1)
test_transformed = test_transformed.drop(['ts2'], axis=1)
# 2. Scale based on train set
train_data_scaled, test_data_scaled, scaler_X, scaler_Y = scale_data(train_transformed, test_transformed, 'ts1')
# 3. Create supervised learning data by adding datetime features and lagged features
train_data_df = pd.DataFrame(train_data_scaled, index=train_transformed.index, columns=train_transformed.columns)
test_data_df = pd.DataFrame(test_data_scaled, index=test_transformed.index, columns=test_transformed.columns)
X_train, Y_train = extract_column(train_data_df, 'ts1')
X_test, Y_test = extract_column(test_data_df, 'ts1')


hypothesis = 'H4'+"_split_"+str(n_splits)+"_test_size_"+str(test_size)
experiment = 'Impute_outliers'

results = {}

results = run_experiment(models_and_param_grids, X_train, Y_train, X_test, Y_test, tscv, scaler_Y, hypothesis, experiment)
hypothesis_results[experiment+hypothesis] = results
# Out:
# Outliers shape: (21,)
# Outliers shape: (9,)
#
# Training CART model...
# Fitting 30 folds for each of 72 candidates, totalling 2160 fits
# Best model: DecisionTreeRegressor(max_depth=10, max_features='auto', min_samples_leaf=10,
#                       random_state=42)
# Mean error: 0.02725973638792171
# Standard error: 0.01712004588472734
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  49.979335  2.692541e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 1292040.564577447, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#         lb_stat  lb_pvalue
# 10  7809.660155        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 11571548649.9686, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.1344404270042041
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  21.18022   0.019871
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 72200.23070630543, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  28.759488   0.001363
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5562488.54940538, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training KNN model...
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best model: KNeighborsRegressor(leaf_size=10, n_neighbors=9, weights='distance')
# Mean error: 0.020103748244391508
# Standard error: 0.0033868484320866182
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#     lb_stat  lb_pvalue
# 10      NaN        NaN
# The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: nan, p-value: nan
# The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).
# RMSE: 0.13468358368431785
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  20.093361   0.028382
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 78476.44454900724, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#      lb_stat  lb_pvalue
# 10  23.90111   0.007867
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 5947963.76249002, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training GBR model...
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__max_depth
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmregressor__num_leaves
# Best model: LGBMRegressor(lgbmregressor__learning_rate=0.01, lgbmregressor__max_depth=5,
#               lgbmregressor__n_estimators=100, lgbmregressor__num_leaves=35,
#               random_state=42)
# Mean error: 0.01977259302544378
# Standard error: 0.0
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat     lb_pvalue
# 10  48.844486  4.349416e-07
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 910003.6343172902, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#        lb_stat  lb_pvalue
# 10  6740.72675        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7690491591.556496, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.134958795359257
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  21.590202   0.017334
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 79936.89770146295, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  24.101579   0.007335
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 6155075.969079796, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Training XGB model...
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Best model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)
# Mean error: 0.029541973060589182
# Standard error: 0.022312791867510225
# Residual analysis for train set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  35.351983   0.000109
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 385455.9640153604, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#          lb_stat  lb_pvalue
# 10  11770.917935        0.0
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 988869358.2394568, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# RMSE: 0.13398004138957578
# Residual analysis for test set:
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  22.334933   0.013486
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 82594.74792411215, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
# Residuals quared
#
# Homoscedasticity scatter plot:
# Ljung-Box test for autocorrelation in residuals:
#       lb_stat  lb_pvalue
# 10  24.976666    0.00539
# The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).
#
# Jarque-Bera test for normality in residuals:
# Test statistic: 7243238.6137211025, p-value: 0.0
# The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).
#
# Results:
# CART: Train RMSE: 0.0273, Test RMSE: 0.1344
# KNN: Train RMSE: 0.0201, Test RMSE: 0.1347
# GBR: Train RMSE: 0.0198, Test RMSE: 0.1350
# XGB: Train RMSE: 0.0295, Test RMSE: 0.1340

# %% [markdown]
# ## Data preparation

# %% [markdown]
# - Import data
# - Apply imputation and cleaning methods
# - Transform to returns
# - Resample
# - Split training and holdout

# %%
# make into function
filename = "Test_data.csv"
raw_df = pd.read_csv(filename, header=None)
raw_df.columns = ['datetime', 'ts1', 'ts2']
raw_df['datetime'] = pd.to_datetime(raw_df['datetime']-719529,unit='d').round('s')
raw_df.set_index('datetime', inplace = True)

# %%
def plot_time_series(ts1, ts2, ts1_label='ts1', ts2_label='ts2', figsize=(12, 10)):
    # Create subplots
    fig, axs = plt.subplots(nrows=2, ncols=1, figsize=figsize)

    # Plot first time series on first subplot
    axs[0].plot(ts1)
    axs[0].set_xlabel('Date')
    axs[0].set_ylabel('Price')
    axs[0].set_title(ts1_label)

    # Plot second time series on second subplot
    axs[1].plot(ts2)
    axs[1].set_xlabel('Date')
    axs[1].set_ylabel('Price')
    axs[1].set_title(ts2_label)

# %%
# Function to count missing values in a series
def count_missing_values(series):
    return series.isna().sum()

# Function to find the maximum length of continuous missing values in a series
def max_missing_range(series):
    mask = series.isna()
    changes = mask.ne(mask.shift()).cumsum()
    counts = mask.groupby(changes).sum()
    counts = counts[counts > 1]
    if counts.empty:
        return 0
    else:
        return counts.max()

# Function to impute missing values in a series using a moving mean
def impute_missing_values(series, window):
    if series.isnull().any():
        rolling_mean = series.rolling(window=window, min_periods=1).mean()
        return series.fillna(rolling_mean)
    else:
        return series

# Function to convert intervals to days
def intervals_to_days(intervals):
    minutes = intervals * 2
    hours = minutes / 60
    days = hours / 24
    return days

def rolling_mean(series, window=120):
    if series.isnull().any():
        # Create a copy of the series
        imputed_series = series.copy()
        
        # Identify the non-missing blocks of data
        non_missing_blocks = series.notna().astype(int).groupby(series.isna().astype(int).cumsum()).cumsum()

        # Loop through the non-missing blocks and calculate the rolling mean for each block
        for _, block in non_missing_blocks.groupby(non_missing_blocks):
            start_idx = block.index[0]
            end_idx = block.index[-1] + pd.Timedelta(minutes=2)  # Change this line to fix the error
            rolling_mean_block = series[start_idx:end_idx].rolling(window=window, min_periods=1).mean()
            imputed_series[start_idx:end_idx] = series[start_idx:end_idx].fillna(rolling_mean_block)
        
        imputed_series.fillna(method='bfill', inplace=True)  # Backfill since missing starting data
    else:
        imputed_series = series
    return imputed_series


def impute_missing_values(data, short_gap_threshold=120, long_gap_threshold = 2880): #120 is 240 minutes, 2880 is 4 days

    # Identify the missing value gaps
    missing_gaps = data.isna().astype(int).groupby(data.notna().astype(int).cumsum()).cumsum()

    # Apply moving mean imputation for shorter gaps
    data_short_gaps = data.copy()
    data_short_gaps[missing_gaps <= short_gap_threshold] = rolling_mean(data_short_gaps)
    
    # Apply moving mean imputation for longer gaps
    data_long_gaps = data.copy()
    data_long_gaps[missing_gaps > short_gap_threshold] = rolling_mean(data_long_gaps,long_gap_threshold )

    # Combine the imputed data
    data_imputed = data_short_gaps.combine_first(data_long_gaps)
    
    # Impute any leftover missing values using backfill and forward fill methods
    data_imputed.fillna(method='bfill', inplace=True)  # Backfill
    data_imputed.fillna(method='ffill', inplace=True)  # Forward fill
    
    return data_imputed

def fill_forward_saturdays(series):
    # Make a copy of the series
    filled_series = series.copy()
    # Filter the index to include only Saturdays
    saturday_index = series.index.weekday == 5
    # Forward fill only on Saturdays
    filled_series.loc[saturday_index] = filled_series.loc[saturday_index].fillna(method='ffill')
    # Return the filled series
    return filled_series

# %%
ts1 = raw_df['ts1']
ts2 = raw_df['ts2']

# Get the maximum missing range in ts1 and ts2
max_ts1 = max_missing_range(ts1)
max_ts2 = max_missing_range(ts2)
print(f"Max missing range in ts1: {max_ts1}")
print(f"Max missing range in ts2: {max_ts2}")


# Impute missing values in ts1 and ts2 using their respective maximum missing ranges
imputed_ts1 = impute_missing_values(ts1,long_gap_threshold = max_ts1)
imputed_ts2 = impute_missing_values(ts2, long_gap_threshold = max_ts2)

# Print the number of missing values in the imputed series
print(f"Missing values in imputed ts1: {imputed_ts1.isna().sum()}")
print(f"Missing values in imputed ts2: {imputed_ts2.isna().sum()}")

# Calculate the maximum missing range in the imputed series
max_imputed_ts1 = max_missing_range(imputed_ts1)
max_imputed_ts2 = max_missing_range(imputed_ts2)

# Print the maximum missing range in the imputed series
print(f"Max missing range in imputed ts1: {max_imputed_ts1}")
print(f"Max missing range in imputed ts2: {max_imputed_ts2}")
#PLot original data
# plot_time_series(ts1, ts2)

# Plot the imputed time series
# plot_time_series(imputed_ts1, imputed_ts2)

# %%
clean_df =  pd.concat([imputed_ts1, imputed_ts2], axis=1)
print(clean_df.isna().sum())
ts_1_imp = clean_df['ts1']
ts_2_imp = clean_df['ts2']


rt = np.log(clean_df/clean_df.shift(1))
rt.dropna(inplace=True)
rt_1 = rt['ts1']
rt_2 = rt['ts2']
plot_time_series(rt_1, rt_2, 'rt_1', 'rt_2')
print(rt.isna().sum())

# %%
clean_df.to_csv('clean_df.csv')

# %%
# rt.to_csv('rt_c.csv', index=True)
print((rt == 0).sum())
rt.describe()

# %% [markdown]
# Data preparation

# %%
# def create_holdout_validation_set(data, days=30):
#     validation_start_date = data.index.max() - pd.DateOffset(days=days - 1)
#     train_data = data[data.index < validation_start_date]
#     validation_data = data[data.index >= validation_start_date]

#     return train_data, validation_data

def split_time_series(data, percent_train):
    n_train = int(len(data) * percent_train)
    train_data = data.iloc[:n_train]
    test_data = data.iloc[n_train:]

    return train_data, test_data

# %%
# resample to daily frequency for forecasting
# create holdout set of last month for OOS validation

clean_df_daily = clean_df.resample('D').mean()
ts_1_D = clean_df_daily['ts1']
ts_2_D = clean_df_daily['ts2']
# #create holdout set of last month for OOS validation
ts_1_D_train, ts_1_D_validation = split_time_series(ts_1_D, 0.8)
ts_2_D_train, ts_2_D_validation = split_time_series(ts_2_D, 0.8)

rt_daily = rt.resample('D').mean()
rt_1_D = rt_daily['ts1']
rt_2_D = rt_daily['ts2']
#create holdout set of last month for OOS validation
rt_1_D_train, rt_1_D_validation = split_time_series(rt_1_D, 0.8)
rt_2_D_train, rt_2_D_validation = split_time_series(rt_2_D, 0.8)

# %%
# rt_daily.to_csv('rt_daily.csv', index=True)
(rt_daily==0).sum()

# %% [markdown]
# a. Feature engineering

# %%
# Define a function for rolling forecast origin split
def rolling_forecast_origin_split(data, window_size):
    # Iterate through the data using a rolling window
    for i in range(window_size, len(data)):
        # Split the data into training and testing sets
        train_data = data[:i-window_size]
        test_data = data[i-window_size:i]
        # Yield the training and testing sets
        yield train_data, test_data
        

def create_lagged_features(series, lag=1):
    # Create a DataFrame from the input series
    df = pd.DataFrame(series)
    
    # Create lagged features
    for i in range(1, lag + 1):
        df[f"lag_{i}"] = df.shift(i)
    
    # Drop rows with missing values caused by shifting
    df.dropna(inplace=True)
    
    return df

def generate_lagged_features(ts_data, var, max_lag):
    for t in range(1, max_lag+1):
        ts_data[var+'_lag'+str(t)] = ts_data[var].shift(t, freq='1D')
    ts_data.dropna(inplace=True)

# %% [markdown]
# Benchmark

# %% [markdown]
# Univariate
# - b. Training
# - c. Testing

# %%
# make return the model as well
def fit_arima(train_data, test_data):
    # Use auto_arima to select the best ARIMA model
    model = sm.tsa.arima.auto_arima(train_data, seasonal=False, suppress_warnings=True)
    arima_preds = model.predict(start=len(train_data), end=len(train_data)+len(test_data)-1)
    # Return the fitted model
    return model, arima_preds


# Function to fit an ARIMA model
def fit_arima(train_data, test_data):
    # Fit an ARIMA model to the training data
    arima_model = ARIMA(train_data, order=(1, 0, 1)).fit(disp=0)
    # Generate predictions for the test data using the fitted model
    arima_preds = arima_model.predict(start=len(train_data), end=len(train_data)+len(test_data)-1)
    return arima_preds, arima_model

# Function to fit a GARCH model
def fit_garch(train_data, test_data):
    # Fit a GARCH model to the training data
    garch_model = arch_model(train_data, vol='Garch', p=1, o=0, q=1).fit(disp='off')
    # Generate predictions for the test data using the fitted model
    garch_preds = garch_model.forecast(horizon=len(test_data)).mean.iloc[-1].values
    return garch_preds, garch_model

# Function to fit a VAR model
def fit_var(train_data, test_data):
    # Fit a VAR model to the training data
    model = VAR(train_data)
    fit_model = model.fit()
    lag_order = results.k_ar
    # Generate predictions for the test data using the fitted model
    preds = fit_model.forecast(train_data.values[-lag_order:], len(test_data))
    return preds, fit_model


def tune_sarima(y_train, seasonal=True):
    model = pm.auto_arima(y_train,
                          seasonal=seasonal,
                          stepwise=True,
                          suppress_warnings=True,
                          trace=True)
    return model


def analyze_model(model):
    # Generate diagnostic plots for the model
    fig, ax = plt.subplots(figsize=(12, 8))
    plot_acf(model.resid, ax=ax, lags=30)
    plt.show()

    fig, ax = plt.subplots(figsize=(12, 8))
    plot_pacf(model.resid, ax=ax, lags=30)
    plt.show()

    fig, ax = plt.subplots(figsize=(12, 8))
    model.plot_diagnostics(ax=ax)
    plt.show()

    # Print a summary of the model
    print(model.summary())

# %% [markdown]
# Multivariate
# - b. Training
# - c. Testing

# %%
def train_random_forest(train_x, train_y, test_x, test_y):
    model = RandomForestRegressor()
    model.fit(train_x, train_y)
    preds = model.predict(test_x)
    mse, mae, mape = evaluate_predictions(test_y, preds)

    print("Random Forest")
    print(f"MSE: {mse:.3f}")
    print(f"MAE: {mae:.3f}")
    print(f"MAPE: {mape:.3f}")
    
    return mse, mae, mape

def train_lightgbm(train_x, train_y, test_x, test_y):
    # Fit LightGBM model
    params = {'objective': 'regression'}
    d_train = lgb.Dataset(train_x, label=train_y)
    model = lgb.train(params, d_train)
    preds = model.predict(test_x)

    # Evaluate predictions
    mse, mae, mape = evaluate_predictions(test_y, preds)

    print("LightGBM")
    print(f"MSE: {mse:.3f}")
    print(f"MAE: {mae:.3f}")
    print(f"MAPE: {mape:.3f}")
    
    return mse, mae, mape



def create_dataset(dataset, look_back=1):
    data_x, data_y = [], []
    for i in range(len(dataset) - look_back):
        data_x.append(dataset[i:(i + look_back), 0])
        data_y.append(dataset[i + look_back, 0])
    return np.array(data_x), np.array(data_y)

def unscale_data(pred, actual):
    scaler = MinMaxScaler()
    scaler.fit(actual)
    pred = scaler.inverse_transform(pred)
    actual = scaler.inverse_trans
    form(actual)
    return pred, actual


def scale_data(train_data, test_data):
    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train_data)
    test_scaled = scaler.transform(test_data)
    return train_scaled, test_scaled


def fit_lstm(train_x, train_y, test_x, test_y, lstm_units=50, look_back=1, num_epochs=10, batch_size=32):
    # Reshape input to be [samples, time steps, features]
    train_x = train_x.reshape((train_x.shape[0], look_back, 1))
    test_x = test_x.reshape((test_x.shape[0], look_back, 1))

    # Build LSTM model
    model = Sequential()
    model.add(LSTM(8, input_shape=(look_back, 1), return_sequences=True))
    model.add(LSTM(4))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mape'])

    # Fit the model
    model.fit(train_x, train_y, epochs=num_epochs, batch_size=batch_size, verbose=2)

    # Make predictions
    train_pred = model.predict(train_x)
    test_pred = model.predict(test_x)

    # Inverse scaling of the predictions
    train_pred = scaler.inverse_transform(train_pred)
    train_y = scaler.inverse_transform(train_y)
    test_pred = scaler.inverse_transform(test_pred)
    test_y = scaler.inverse_transform(test_y)

    # Create a DataFrame of the predictions and actual values
    train_results = pd.DataFrame({'Actual': train_y.flatten(), 'Predicted': train_pred.flatten()}, index=train_data.index[1:])
    test_results = pd.DataFrame({'Actual': test_y.flatten(), 'Predicted': test_pred.flatten()}, index=test_data.index[1:])

    # Evaluate the predictions
    train_mse, train_mae, train_mape = evaluate_predictions(train_y, train_pred)
    test_mse, test_mae, test_mape = evaluate_predictions(test_y, test_pred)
    
    # Evaluate the model on the test set
    loss = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test loss: {loss}")

    # Print the evaluation metrics
    print("Train MSE: {:.3f}, Train MAE: {:.3f}, Train MAPE: {:.3f}".format(train_mse, train_mae, train_mape))
    print("Test MSE: {:.3f}, Test MAE: {:.3f}, Test MAPE: {:.3f}".format(test_mse, test_mae, test_mape))

    return pd.concat([train_results, test_results])



def build_lstm_model(units=50, activation='relu', optimizer='adam'):
    model = Sequential()
    model.add(LSTM(units=units, activation=activation))
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

def tune_lstm(X_train, y_train):
    param_grid = {
        'units': [50, 100],
        'activation': ['relu', 'tanh'],
        'optimizer': [Adam(learning_rate=0.001), Adam(learning_rate=0.01)]
    }
    model = KerasRegressor(build_fn=build_lstm_model, epochs=50, batch_size=32, verbose=0)
    tscv = TimeSeriesSplit(n_splits=5)
    grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=tscv, scoring='neg_mean_squared_error')
    grid_result = grid.fit(X_train, y_train)
    best_params = grid_result.best_params_
    best_lstm_model = build_lstm_model(**best_params)
    best_lstm_model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=0)
    
    print(f"Best LSTM model with parameters {best_params}")
    return best_lstm_model

# %% [markdown]
# OPtimisation

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=100, random_state=42)
forest_reg.fit(housing_prepared, housing_labels)
housing_predictions = forest_reg.predict(housing_prepared)
forest_mse = mean_squared_error(housing_labels, housing_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, housing_prepared, housing_labels,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
scores = cross_val_score(lin_reg, housing_prepared, housing_labels, scoring="neg_mean_squared_error", cv=10)
pd.Series(np.sqrt(-scores)).describe()
#####

from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")
svm_reg.fit(housing_prepared, housing_labels)
housing_predictions = svm_reg.predict(housing_prepared)
svm_mse = mean_squared_error(housing_labels, housing_predictions)
svm_rmse = np.sqrt(svm_mse)
svm_rmse

###


tree_reg1 = DecisionTreeRegressor(random_state=42)
tree_reg2 = DecisionTreeRegressor(random_state=42, min_samples_leaf=10)
tree_reg1.fit(X, y)
tree_reg2.fit(X, y)


#####
from sklearn.model_selection import GridSearchCV

params = {'max_leaf_nodes': list(range(2, 100)), 'min_samples_split': [2, 3, 4]}
grid_search_cv = GridSearchCV(DecisionTreeClassifier(random_state=42), params, verbose=1, cv=3)

grid_search_cv.fit(X_train, y_train)

grid_search_cv.best_estimator_

from sklearn.metrics import accuracy_score

y_pred = grid_search_cv.predict(X_test)
accuracy_score(y_test, y_pred)

from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap set as False
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)
grid_search.fit(housing_prepared, housing_labels)

grid_search.best_params_
grid_search.best_estimator_
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)

# %% [markdown]
# d. Evaluation

# %%
# def evaluate(y_true, y_pred):
#     mae = mean_absolute_error(y_true, y_pred)
#     mse = mean_squared_error(y_true, y_pred)
#     rmse = np.sqrt(mse)
#     mape = mean_absolute_percentage_error(y_true, y_pred)
#     r2 = r2_score(y_true, y_pred)
#     # msle = mean_squared_log_error(y_true, y_pred)

#     return {
#         'mae': mae,
#         'mse': mse,
#         'rmse': rmse,
#         'mape': mape,
#         'r2': r2,
#     }
    
def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    # msle = mean_squared_log_error(y_true, y_pred)
    return {
        'rmse': rmse,
    }

# %% [markdown]
# e. Cross validation

# %%
def rolling_window_kfold_validation(model, X_train, y_train, window_size=30, n_splits=5):

    cv_scores = defaultdict(list)
    kf = KFold(n_splits=n_splits, shuffle=False)
    for train_index, test_index in kf.split(X_train):
        X_train_fold, X_test_fold = X_train[train_index], X_train[test_index]
        y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]
        y_pred_fold = []
        
        for X_train_window, y_train_window, X_test_window, y_test_window in rolling_forecast_origin_split(X_train_fold, y_train_fold, window_size):
            model.fit(X_train_window, y_train_window)
            y_pred_window = model.predict(X_test_window)
            y_pred_fold.extend(y_pred_window)

        evaluation_result = evaluate(y_test_fold, y_pred_fold)

        for metric, value in evaluation_result.items():
            cv_scores[metric].append(value)

    # Calculate the mean and standard deviation of the cross-validation scores
    mean_std_cv_scores = {}
    for metric, scores in cv_scores.items():
        mean_std_cv_scores[metric] = {'mean': np.mean(scores), 'std': np.std(scores)}

    return mean_std_cv_scores

# %% [markdown]
# Select best model: H1 H2 H3 H4 BIC
#
# Optimization of best model

# %% [markdown]
# f. Residual and diagnostic

# %%
#   def residual_analysis(model, data1, data2):
#         # perform residual analysis and return the plot and print statements
#     residuals = model.resid
#     fig, ax = plt.subplots(figsize=(12, 6))
#     ax.plot(residuals)
#     ax.axhline(y=0, color='r', linestyle='-')
#     ax.set_xlabel('Time')
#     ax.set_ylabel('Residuals')
#     ax.set_title('Residual Analysis')
#     plt.show()
#     print('Residual Analysis:')
#     print('Mean of residuals:', round(residuals.mean(), 4))
#     print('Standard deviation of residuals:', round(residuals.std(), 4))

def diagnostics(model, data1, data2):
    # perform diagnostics and return the print statements
    print('Diagnostics:')
    print(model.summary())


#write this so that it takes the predicted values and the actual values
  
def residual_analysis(y_pred, y_train):

    # Calculate the residuals
    residuals = y_train - y_pred

    # Plot the residuals
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.plot(residuals)
    ax.axhline(y=0, color='r', linestyle='-')
    ax.set_xlabel('Time')
    ax.set_ylabel('Residuals')
    ax.set_title('Residual Analysis')
    plt.show()
    print('Residual Analysis:')
    print('Mean of residuals:', round(residuals.mean(), 4))
    print('Standard deviation of residuals:', round(residuals.std(), 4))

    # Check for autocorrelation
    print("Autocorrelation plot:")
    plot_acf(residuals)
    plt.show()

    # Check for normality
    print("Normality Q-Q plot:")
    stats.probplot(residuals, dist="norm", plot=plt)
    plt.show()

    # Check for homoscedasticity
    print("Homoscedasticity scatter plot:")
    plt.scatter(y_pred, residuals)
    plt.xlabel("Predicted values")
    plt.ylabel("Residuals")
    plt.axhline(y=0, color="r", linestyle="--")
    plt.show()

    # Perform Ljung-Box test for autocorrelation in residuals
    lb_test = acorr_ljungbox(residuals, lags=[10], return_df=True)  
    print("Ljung-Box test for autocorrelation in residuals:")
    print(lb_test)
    # Assess the p-value of the Ljung-Box test
    p_value = lb_test['lb_pvalue'][10]
    if p_value < 0.05:
        print("The Ljung-Box test suggests that there is autocorrelation in the residuals (p-value < 0.05).")
    else:
        print("The Ljung-Box test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).")
        
    # Perform Breusch-Godfrey test for autocorrelation in residuals
    bg_test = acorr_breusch_godfrey(model, X_train, nlags=10)
    print("\nBreusch-Godfrey test for autocorrelation in residuals:")
    if bg_test[1] < 0.05:
        print(f"LM test statistic: {bg_test[0]}, p-value: {bg_test[1]}")
        print("The Breusch-Godfrey test suggests that there is autocorrelation in the residuals (p-value < 0.05).")
    else:
        print(f"LM test statistic: {bg_test[0]}, p-value: {bg_test[1]}")
        print("The Breusch-Godfrey test suggests that there is no significant autocorrelation in the residuals (p-value >= 0.05).")

    # Perform Jarque-Bera test for normality in residuals
    jb_test = jarque_bera(residuals)
    print("\nJarque-Bera test for normality in residuals:")
    if jb_test[1] < 0.05:
        print(f"Test statistic: {jb_test[0]}, p-value: {jb_test[1]}")
        print("The Jarque-Bera test suggests that the residuals are not normally distributed (p-value < 0.05).")
    else:
        print(f"Test statistic: {jb_test[0]}, p-value: {jb_test[1]}")
        print("The Jarque-Bera test suggests that the residuals are normally distributed (p-value >= 0.05).")

    # Perform White test for heteroscedasticity in residuals
    white_test = het_white(residuals, X_train)
    print("\nWhite test for heteroscedasticity in residuals:")
    if white_test[1] < 0.05:
        print(f"Test statistic: {white_test[0]}, p-value: {white_test[1]}")
        print("The White test suggests that there is heteroscedasticity in the residuals (p-value < 0.05).")
    else:
        print(f"Test statistic: {white_test[0]}, p-value: {white_test[1]}")
        print("The White test suggests that there is no significant heteroscedasticity in the residuals (p-value >= 0.05).")

    # Perform Shapiro-Wilk test for normality in residuals
    sw_test = shapiro(residuals)
    print("\nShapiro-Wilk test for normality in residuals:")
    if sw_test[1] < 0.05:
        print(f"Test statistic: {sw_test[0]}, p-value: {sw_test[1]}")
        print("The Shapiro-Wilk test suggests that the residuals are not normally distributed (p-value < 0.05).")
    else:
        print(f"Test statistic: {sw_test[0]}, p-value: {sw_test[1]}")
        print("The Shapiro-Wilk test suggests that the residuals are normally distributed (p-value >= 0.05).")





# This function first fits the model to the provided training data and calculates the residuals. It then plots the autocorrelation, normality Q-Q plot, and homoscedasticity scatter plot. Finally, it performs the Ljung-Box test for autocorrelation in the residuals and assesses the p-value of the test.

    
  


# def residual_analysis(model, X_train, y_train):
#     # predict on the training data
#     y_pred = model.predict(X_train)

#     # Calculate the residuals
#     residuals = y_train - y_pred

#     # Check for autocorrelation
#     print("Autocorrelation plot:")
#     plot_acf(residuals)
#     plt.show()

#     # Check for normality
#     print("Normality Q-Q plot:")
#     stats.probplot(residuals, dist="norm", plot=plt)
#     plt.show()

#     # Check for homoscedasticity
#     print("Homoscedasticity scatter plot:")
#     plt.scatter(y_pred, residuals)
#     plt.xlabel("Predicted values")
#     plt.ylabel("Residuals")
#     plt.axhline(y=0, color="r", linestyle="--")
#     plt.show()

#     # Perform Ljung-Box test for autocorrelation in residuals
#     lb_test = acorr_ljungbox(residuals, lags=[10], return_df=True)
#     print("Ljung-Box test for autocorrelation in residuals:")
#     print(lb_test)

# %% [markdown]
# Forecast and confidence intervals

# %%
from scipy import stats

confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors) - 1,
                         loc=squared_errors.mean(),
                         scale=stats.sem(squared_errors)))

# %% [markdown]
# ** Save plot output from each method to file and folder

# %% [markdown]
# ## Testing

# %% [markdown]
# Univariate:

# %% [markdown]
# Benchmarking

# %% [markdown]
# H1

# %%
#         # Split the data into features and labels
#         X, y = dataset_combination[0], dataset_combination[1]
#         # Iterate through the rolling forecast origin split
#         for X_train, y_train, X_test, y_test in rolling_forecast_origin_split(X, y, window_size=30):
#             # Train and test the model
#             y_pred = predict_funct(X_train, y_train, X_test)
#             # Evaluate the model
#             accuracy, precision, recall = evaluate_model(y_test, y_pred)
#             # Evaluate the predictions
#             evaluation_result = evaluate(y_pred, y_test)

#             # Print the evaluation metrics
#             print(f"Model: {model_name}, Dataset Combination: {dataset_combination}")
#             print(f'Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}')
#             print(f"Evaluation result: {evaluation_result}")

#             # Append the evaluation results to the model_evaluations list
#             evaluation_result.update({'model_name': model_name})
#             model_evaluations.append(evaluation_result)

#             # Train and test the model
#             train_func(train_data)
#             predictions = test_func(test_data)

#             # Evaluate the predictions
#             evaluation_result = evaluate(predictions, test_data)

#         # Output the evaluation and CV results
#             print(f"Model: {model_name}, Train data: {train_data}, Test data: {test_data}")
#             print(f"Evaluation result: {evaluation_result}")

#             # Append the evaluation results to the model_evaluations list
#             evaluation_result.update({'model_name': model_name})
#             model_evaluations.append(evaluation_result)

# %% [markdown]
# Trad
# - ARIMA
# - GARCH (depending on correlation of residuals fo ARIMA)

# %%
ts_1_imp = clean_df['ts1']
ts_2_imp = clean_df['ts2']

rt_1_D_train, rt_2_D_train
import pandas as pd
from pmdarima.arima import auto_arima
from pmdarima.model_selection import cross_validate
from pmdarima.model_selection import RollingForecastCV

def plot_correlogram(x, lags=None, title=None):
    lags = min(10, int(len(x)/5)) if lags is None else lags
    with sns.axes_style('whitegrid'):
        fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 8))
        x.plot(ax=axes[0][0], title='Residuals')
        x.rolling(21).mean().plot(ax=axes[0][0], c='k', lw=1)
        q_p = np.max(q_stat(acf(x, nlags=lags), len(x))[1])
        stats = f'Q-Stat: {np.max(q_p):>8.2f}\nADF: {adfuller(x)[1]:>11.2f}'
        axes[0][0].text(x=.02, y=.85, s=stats, transform=axes[0][0].transAxes)
        probplot(x, plot=axes[0][1])
        mean, var, skew, kurtosis = moment(x, moment=[1, 2, 3, 4])
        s = f'Mean: {mean:>12.2f}\nSD: {np.sqrt(var):>16.2f}\nSkew: {skew:12.2f}\nKurtosis:{kurtosis:9.2f}'
        axes[0][1].text(x=.02, y=.75, s=s, transform=axes[0][1].transAxes)
        plot_acf(x=x, lags=lags, zero=False, ax=axes[1][0])
        plot_pacf(x, lags=lags, zero=False, ax=axes[1][1])
        axes[1][0].set_xlabel('Lag')
        axes[1][1].set_xlabel('Lag')
        fig.suptitle(title, fontsize=14)
        sns.despine()
        fig.tight_layout()
        fig.subplots_adjust(top=.9)

# %% [markdown]
# Split train test
# with train:
#     rolling cv with grid search to find best params
#         grid search
#             rolling cv of train and predict
#             list of cv score
#             list of models
#         Best params from smallest error

# %%
model = auto_arima(rt_1_D_train, seasonal=False, trace=True, error_action='ignore', suppress_warnings=True, stepwise=True)
model.get_params()
in_sample_predictions = model.predict_in_sample()
model.fit(rt_1_D_train)
Evaluate the model on the test data
predictions = model.predict(n_periods=len(test_data), exogenous=test_data.drop('target_variable', axis=1))
Do something with the predictions
plot the predictions for validation set
plot_time_series(rt_1_D_train, in_sample_predictions)

# %%
# corss valid and train auto arima
# Define the rolling forecast cross validation object

# cv_results = cross_validate(
#     model,  # the auto_arima model
#     rt_1_D_train,  # the target variable
#     cv=rfcv,  # number of cross-validation folds
#     scoring = evaluate,  # return the fitted models
#     verbose=2  # print progress messages
# )
# Iterate over the splits and fit an auto arima model to each split
model_params = []
evaluation_results = []
models = []
for train_index, test_index in rfcv.split(rt_1_D_train):
    train_data = rt_1_D_train.iloc[train_index]
    test_data = rt_1_D_train.iloc[test_index]

rfcv = RollingForecastCV(
    h=170,  # forecast horizon
    step=30,  # step size
)
for train_index, test_index in rfcv.split(data):
    train_data = data.iloc[train_index]
    test_data = data.iloc[test_index]
    model = train_model(train_data, config)
    prediction = model_predict(model, train_data, cfg)
    predictions.append(prediction)
    evaluation_result = evaluate(test_data, prediction)
    evaluation_results.append(evaluation_result)


#     model = auto_arima(train_data, seasonal=False, trace=True, error_action='ignore', suppress_warnings=True, stepwise=True)
#     model.fit(train_data)
#     models.append(model)
#     model_params.append(model.get_params())
#     in_sample_predictions = model.predict_in_sample()
#     evaluation_result = evaluate(in_sample_predictions, train_data)
#     evaluation_results.append(evaluation_result)

#roling window cross vlaidation for model traning and grid search

# %%
def grid_search(data, cfg_list):
    scores_and_models = {}
    for cfg in cfg_list:
        score, model = walk_forward_validation(data, cfg)
        scores_and_models[cfg] = {'score': score, 'model': model}
    
    # Calculate mean and standard deviation of scores
    scores = [v['score'] for v in scores_and_models.values()]
    mean_score = np.mean(scores)
    std_score = np.std(scores)
    
    return scores_and_models, mean_score, std_score


def train_model(train, config):
    order = config
    model = ARIMA(train, order=order)
    model_fit = model.fit()
    return model_fit

def model_predict(model, start, end):
    return model.predict(start=start, end=end)

def evaluate(test_data, prediction):
    return measure_rmse(test_data, prediction)

def walk_forward_validation(data, cfg):
    rfcv = RollingForecastCV(h=170, step=30)
    evaluation_results = []

    for train_index, test_index in rfcv.split(data):
        train_data = data[train_index]
        test_data = data[test_index]
        model_fit = train_model(train_data, cfg)
        prediction = model_predict(model_fit, start=len(train_data), end=len(train_data)+len(test_data)-1)
        evaluation_result = evaluate(test_data, prediction)
        evaluation_results.append(evaluation_result)

    return np.mean(evaluation_results), model_fit

# %%
in_sample_predictions = model.predict_in_sample()
plot_time_series(rt_1_D_train, in_sample_predictions)

# %%
test_scores = cv_results['test_score']
min_rmse_dict = min(test_scores, key=lambda x: x['rmse'])
print(min_rmse_dict)

# %%
test_scores = cv_results['test_score']
min_rmse_dict = min(test_scores, key=lambda x: x['rmse'])
print(min_rmse_dict)
# Get the order of the best model
best_model_idx = cv_results['test_score'].argmax()
best_model = cv_results['estimator'][best_model_idx]
best_order = best_model.order

# Print the order of the best model
print(f"The order of the best auto_arima model is {best_order}")

# %%
#functions for training and evaluation of model training for trad models
# just passing training data to the model
def train_and_evaluate_model(predict_funct, train_data, test_data):
    # Train and test the model
    y_pred, fitted_model = predict_funct(X_train, y_train)

    # Evaluate the predictions
    evaluation_result = evaluate(y_pred, y_test)

    return evaluation_result, fitted_model


train_and_evaluate_model(fit_arima, ts_1_imp[[:]], test_data)

# %%
for train_data, test_data in rolling_forecast_origin_split(X, window_size=30):
    # Get the fitting function for the current model
    predict_funct = MODEL_FUNCTIONS[model_name]

    # Train, test and evaluate the model
    evaluation_result, fitted_model = train_and_evaluate_model(predict_funct, train_data, test_data)

    # You can now access the fitted model object and use its methods
    print(f"Fitted model: {fitted_model}")

# %%
#residual
# Split the data into features and labels
X, y = dataset_combination[0], dataset_combination[1]
# Iterate through the rolling forecast origin split
for X_train, y_train, X_test, y_test in rolling_forecast_origin_split(X, y, window_size=30):

    # Perform residual analysis
    residual_analysis(model_name, test_func, test_data)

    # Perform diagnostics
    diagnostics(model_name, test_func, test_data)
    print(f"Cross-validation result: {cv_result}")
    print(f"Residual analysis result: {residual_result}")
    print(f"Diagnostics result: {diagnostics_result}")
    print("\n")

# %% [markdown]
# Feature engineering ML

# %% [markdown]
# ML
# - RF
# - SVM
# - LightGBM
# - LSTM

# %% [markdown]
# H2
# - ARIMA
# - GARCH (depending on correlation of residuals fo ARIMA)

# %% [markdown]
# Feature engineering ML

# %% [markdown]
# ML
# - RF
# - SVM
# - LightGBM
# - LSTM

# %% [markdown]
# H1,H2
#
# Optimization of best model
#
# Residual and diagnostic

# %% [markdown]
# Multivariate:

# %% [markdown]
# H3

# %% [markdown]
# Trad
# - VAR

# %% [markdown]
# ML
# - RF
# - SVM
# - LightGBM
# - LSTM

# %% [markdown]
# H4
# - VAR

# %% [markdown]
# H3,H4
#
# Optimization of best model
#
# Residual and diagnostic

# %% [markdown]
# Forecast validation
# - H1
# - H2
# - H3
# - H4
